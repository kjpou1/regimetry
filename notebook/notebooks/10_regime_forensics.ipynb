# %%
import pandas as pd
from os import path

from regimetry.config import Config
from regimetry.logger_manager import LoggerManager

# %%
logging = LoggerManager.get_logger("positional_encoding.ipynb")

# %%
cfg = Config()
print("PROJECT ROOT:", cfg.PROJECT_ROOT)
print("BASE DIR:", cfg.BASE_DIR)
print("RAW DATA:", cfg.RAW_DATA_DIR)
print("PROCESSED DATA:", cfg.PROCESSED_DATA_DIR)
print("EMBEDDINGS DATA:", cfg.EMBEDDINGS_DIR) 
print("REPORTS DATA:", cfg.REPORTS_DIR)
# Out:
# PROJECT ROOT: /Users/kenneth/Public/projects/python/ai/regimetry
# BASE DIR: /Users/kenneth/Public/projects/python/ai/regimetry/artifacts
# RAW DATA: /Users/kenneth/Public/projects/python/ai/regimetry/artifacts/data/raw
# PROCESSED DATA: /Users/kenneth/Public/projects/python/ai/regimetry/artifacts/data/processed
# EMBEDDINGS DATA: /Users/kenneth/Public/projects/python/ai/regimetry/artifacts/embeddings
# REPORTS DATA: /Users/kenneth/Public/projects/python/ai/regimetry/artifacts/reports

# %% [markdown]
# ## 🧩 Step 1: Load + Compute Per-Cluster Means

# %% [markdown]
# ### 📥 Load:

# %%
cluster_path = path.join(cfg.REPORTS_DIR,"CAD_CHF_ws5_learnable80_nc12", "cluster_assignments.csv")
df = pd.read_csv(cluster_path)
df["Cluster_ID"] = pd.to_numeric(df["Cluster_ID"], errors="coerce")
df = df.dropna(subset=["Cluster_ID"]).copy()
df["Cluster_ID"] = df["Cluster_ID"].astype(int)

# %% [markdown]
# ### 📊 Group + Aggregate:

# %%
# Find all object or categorical-type columns
cat_columns = df.select_dtypes(include=["object", "category"]).columns.tolist()
print("Categorical columns detected:", cat_columns)
# Out:
# Categorical columns detected: ['ML_Trade_Direction', 'ML_Signal_Quality', 'Prevailing_Trend', 'Baseline_Aligned', 'Trend_Agreement', 'Entry_Trigger', 'Entry_Confirmed', 'RHD_Bull', 'RHD_Bear']

# %%
df[cat_columns]
# Out:
#      ML_Trade_Direction ML_Signal_Quality Prevailing_Trend Baseline_Aligned  \
# 4                  Sell              Weak          Bearish             Flat
# 5                   Buy            Strong             Flat             Flat
# 6                  Flat          Moderate             Flat             Flat
# 7                   Buy            Strong          Bullish             Flat
# 8                  Flat              Weak          Bullish          Bullish
# ...                 ...               ...              ...              ...
# 1869                Buy            Strong          Bullish             Flat
# 1870               Sell            Strong          Bullish          Bullish
# 1871               Flat              Weak             Flat             Flat
# 1872               Sell            Strong             Flat             Flat
# 1873               Flat              Weak             Flat             Flat
#
#      Trend_Agreement Entry_Trigger Entry_Confirmed RHD_Bull RHD_Bear
# 4               Flat          Flat            Flat   Strong   Strong
# 5               Flat          Flat            Flat   Strong   Strong
# 6               Flat          Flat            Flat   Strong     Weak
# 7               Flat          Flat            Flat   Strong   Strong
# 8            Bullish       Bullish            Flat   Strong   Strong
# ...              ...           ...             ...      ...      ...
# 1869            Flat          Flat            Flat   Strong   Strong
# 1870         Bullish       Bullish         Bullish   Strong   Strong
# 1871            Flat          Flat            Flat   Strong   Strong
# 1872            Flat          Flat            Flat     Weak   Strong
# 1873            Flat          Flat            Flat     Weak   Strong
#
# [1870 rows x 9 columns]

# %%
cat_df = df[["Cluster_ID"] + cat_columns]
cat_modes = cat_df.groupby("Cluster_ID").agg(lambda x: x.value_counts().idxmax()).add_suffix("_mode").reset_index()
cat_dominance = cat_df.groupby("Cluster_ID").agg(lambda x: x.value_counts(normalize=True).iloc[0]).add_suffix("_dominance").reset_index()

cat_summary = cat_modes.merge(cat_dominance, on="Cluster_ID")

# %%
cat_summary
# Out:
#     Cluster_ID ML_Trade_Direction_mode ML_Signal_Quality_mode  \
# 0            0                    Flat                 Strong
# 1            1                    Flat                   Weak
# 2            2                    Sell                   Weak
# 3            3                    Flat                 Strong
# 4            4                    Flat                 Strong
# 5            5                    Flat                   Weak
# 6            6                    Flat                   Weak
# 7            7                    Flat                 Strong
# 8            8                    Flat                   Weak
# 9            9                    Flat                   Weak
# 10          10                    Flat                   Weak
# 11          11                    Flat                   Weak
#
#    Prevailing_Trend_mode Baseline_Aligned_mode Trend_Agreement_mode  \
# 0                   Flat                  Flat                 Flat
# 1                   Flat                  Flat                 Flat
# 2                   Flat                  Flat                 Flat
# 3                   Flat                  Flat                 Flat
# 4                   Flat                  Flat                 Flat
# 5                   Flat                  Flat                 Flat
# 6                   Flat                  Flat                 Flat
# 7                   Flat                  Flat                 Flat
# 8                Bullish                  Flat                 Flat
# 9                   Flat                  Flat                 Flat
# 10                  Flat                  Flat                 Flat
# 11                  Flat                  Flat                 Flat
#
#    Entry_Trigger_mode Entry_Confirmed_mode RHD_Bull_mode RHD_Bear_mode  \
# 0                Flat                 Flat        Strong        Strong
# 1                Flat                 Flat        Strong        Strong
# 2                Flat                 Flat        Strong        Strong
# 3                Flat                 Flat        Strong        Strong
# 4                Flat                 Flat        Strong        Strong
# 5                Flat                 Flat        Strong        Strong
# 6                Flat                 Flat        Strong        Strong
# 7                Flat                 Flat        Strong        Strong
# 8                Flat                 Flat        Strong        Strong
# 9                Flat                 Flat        Strong        Strong
# 10               Flat                 Flat        Strong        Strong
# 11               Flat                 Flat        Strong        Strong
#
#     ML_Trade_Direction_dominance  ML_Signal_Quality_dominance  \
# 0                       0.448161                     0.431438
# 1                       0.483740                     0.414634
# 2                       0.347826                     0.478261
# 3                       0.444915                     0.444915
# 4                       0.443983                     0.460581
# 5                       0.455882                     0.411765
# 6                       0.400000                     0.430000
# 7                       0.366667                     0.477778
# 8                       0.454545                     0.454545
# 9                       0.375000                     0.500000
# 10                      0.394118                     0.458824
# 11                      0.411765                     0.470588
#
#     Prevailing_Trend_dominance  Baseline_Aligned_dominance  \
# 0                     0.488294                    0.668896
# 1                     0.556911                    0.747967
# 2                     0.434783                    0.869565
# 3                     0.563559                    0.822034
# 4                     0.593361                    0.751037
# 5                     0.566176                    0.875000
# 6                     0.510000                    0.720000
# 7                     0.577778                    0.755556
# 8                     0.454545                    0.636364
# 9                     0.625000                    0.666667
# 10                    0.564706                    0.676471
# 11                    0.495098                    0.730392
#
#     Trend_Agreement_dominance  Entry_Trigger_dominance  \
# 0                    0.769231                 0.836120
# 1                    0.813008                 0.849593
# 2                    0.913043                 0.913043
# 3                    0.872881                 0.851695
# 4                    0.804979                 0.958506
# 5                    0.926471                 0.955882
# 6                    0.810000                 0.880000
# 7                    0.822222                 0.883333
# 8                    0.818182                 0.818182
# 9                    0.875000                 0.875000
# 10                   0.752941                 0.852941
# 11                   0.784314                 0.882353
#
#     Entry_Confirmed_dominance  RHD_Bull_dominance  RHD_Bear_dominance
# 0                    0.963211            0.866221            0.969900
# 1                    0.967480            0.894309            0.939024
# 2                    0.956522            0.826087            0.956522
# 3                    0.961864            0.906780            0.932203
# 4                    0.987552            0.995851            0.829876
# 5                    0.985294            0.926471            0.977941
# 6                    1.000000            0.960000            0.860000
# 7                    0.950000            0.888889            0.950000
# 8                    1.000000            0.818182            1.000000
# 9                    0.958333            0.875000            0.958333
# 10                   0.964706            0.888235            0.935294
# 11                   0.975490            0.970588            0.926471

# %%
# Find all strictly boolean columns
bool_columns = df.select_dtypes(include=["bool"]).columns.tolist()

# Optionally print them
print("Boolean columns detected:", bool_columns)

# Convert to float
df[bool_columns] = df[bool_columns].astype(float)

# These will show up in the .mean() aggregation as:
#  RHD_Bear_mean = 0.48 → "48% of windows had a bearish divergence"
# Out:
# Boolean columns detected: []

# %%
# Now, select all numeric columns including the newly-converted bools
df_numeric = df.select_dtypes(include=["number"])

# Regenerate the summary only on numerics
cluster_summary = df_numeric.groupby("Cluster_ID").agg(["mean", "std"]).round(4)
cluster_summary.columns = ['_'.join(col).strip() for col in cluster_summary.columns.values]
cluster_summary.reset_index(inplace=True)

# %%
cluster_summary
# Out:
#     Cluster_ID  Open_mean  Open_std  High_mean  High_std  Low_mean  Low_std  \
# 0            0     0.7444    0.0133     0.7469    0.0131    0.7419   0.0134
# 1            1     0.6398    0.0171     0.6420    0.0170    0.6374   0.0173
# 2            2     0.7297    0.0044     0.7326    0.0043    0.7269   0.0045
# 3            3     0.7466    0.0140     0.7491    0.0139    0.7440   0.0139
# 4            4     0.7430    0.0138     0.7455    0.0137    0.7400   0.0140
# 5            5     0.6508    0.0177     0.6529    0.0176    0.6491   0.0176
# 6            6     0.7491    0.0146     0.7524    0.0144    0.7455   0.0139
# 7            7     0.6931    0.0070     0.6955    0.0072    0.6906   0.0068
# 8            8     0.7212    0.0047     0.7250    0.0040    0.7172   0.0038
# 9            9     0.5955    0.0051     0.5985    0.0046    0.5927   0.0049
# 10          10     0.7046    0.0295     0.7078    0.0295    0.7010   0.0300
# 11          11     0.6680    0.0239     0.6702    0.0242    0.6650   0.0244
#
#     Close_mean  Close_std  Volume_mean  ...  Classic_Divergence_Bull_mean  \
# 0       0.7445     0.0133   23815.0234  ...                        0.1672
# 1       0.6397     0.0172   40736.1585  ...                        0.1382
# 2       0.7296     0.0045  128983.5217  ...                        0.1739
# 3       0.7466     0.0139   24610.6822  ...                        0.0932
# 4       0.7426     0.0139   29557.0747  ...                        0.0083
# 5       0.6512     0.0176   36331.0588  ...                        0.0735
# 6       0.7489     0.0143   98109.3300  ...                        0.0600
# 7       0.6931     0.0072   18749.7556  ...                        0.1222
# 8       0.7215     0.0049  137175.0000  ...                        0.1818
# 9       0.5960     0.0048   43563.1667  ...                        0.1250
# 10      0.7045     0.0300   52604.7824  ...                        0.1294
# 11      0.6675     0.0246   61575.5196  ...                        0.0343
#
#     Classic_Divergence_Bull_std  Classic_Divergence_Bear_mean  \
# 0                        0.3738                        0.0334
# 1                        0.3458                        0.0610
# 2                        0.3876                        0.1304
# 3                        0.2914                        0.1356
# 4                        0.0909                        0.1701
# 5                        0.2620                        0.0368
# 6                        0.2387                        0.1500
# 7                        0.3285                        0.0611
# 8                        0.4045                        0.0000
# 9                        0.3378                        0.0833
# 10                       0.3366                        0.0706
# 11                       0.1825                        0.0931
#
#     Classic_Divergence_Bear_std  Day_Of_Week_mean  Day_Of_Week_std  \
# 0                        0.1801            2.4013           2.0397
# 1                        0.2398            2.3943           2.0906
# 2                        0.3444            2.2174           2.0440
# 3                        0.3431            2.4576           2.1304
# 4                        0.3765            2.3776           2.0255
# 5                        0.1889            2.4412           2.0322
# 6                        0.3589            2.4000           2.0695
# 7                        0.2402            2.4333           2.0770
# 8                        0.0000            2.7273           2.3277
# 9                        0.2823            2.2500           2.0054
# 10                       0.2569            2.4118           2.0885
# 11                       0.2913            2.3186           2.0077
#
#     Month_mean  Month_std  Year_mean  Year_std
# 0       7.1806     3.3729  2019.5251    1.2778
# 1       8.1423     3.3734  2023.7114    0.6955
# 2      10.3043     0.4705  2022.0000    0.0000
# 3       5.7712     3.2444  2019.6780    1.3738
# 4       6.2282     3.3244  2019.6349    1.3962
# 5       4.6691     3.0961  2023.9632    0.6712
# 6       5.3900     1.9535  2022.0000    0.0000
# 7       7.8722     3.3006  2020.2500    0.6591
# 8       9.5455     0.5222  2022.0000    0.0000
# 9       4.4583     0.5090  2025.0000    0.0000
# 10      5.8412     3.1063  2020.8235    1.5437
# 11      4.6176     3.1780  2023.2892    0.8764
#
# [12 rows x 89 columns]

# %%
# Merge numeric and categorical summaries by Cluster_ID
full_cluster_profile = cluster_summary.merge(cat_summary, on="Cluster_ID")

# %%
# Sort by cluster ID for clarity
full_cluster_profile = full_cluster_profile.sort_values("Cluster_ID")

# Preview
full_cluster_profile.head()
# Out:
#    Cluster_ID  Open_mean  Open_std  High_mean  High_std  Low_mean  Low_std  \
# 0           0     0.7444    0.0133     0.7469    0.0131    0.7419   0.0134
# 1           1     0.6398    0.0171     0.6420    0.0170    0.6374   0.0173
# 2           2     0.7297    0.0044     0.7326    0.0043    0.7269   0.0045
# 3           3     0.7466    0.0140     0.7491    0.0139    0.7440   0.0139
# 4           4     0.7430    0.0138     0.7455    0.0137    0.7400   0.0140
#
#    Close_mean  Close_std  Volume_mean  ...  RHD_Bear_mode  \
# 0      0.7445     0.0133   23815.0234  ...         Strong
# 1      0.6397     0.0172   40736.1585  ...         Strong
# 2      0.7296     0.0045  128983.5217  ...         Strong
# 3      0.7466     0.0139   24610.6822  ...         Strong
# 4      0.7426     0.0139   29557.0747  ...         Strong
#
#    ML_Trade_Direction_dominance  ML_Signal_Quality_dominance  \
# 0                      0.448161                     0.431438
# 1                      0.483740                     0.414634
# 2                      0.347826                     0.478261
# 3                      0.444915                     0.444915
# 4                      0.443983                     0.460581
#
#    Prevailing_Trend_dominance  Baseline_Aligned_dominance  \
# 0                    0.488294                    0.668896
# 1                    0.556911                    0.747967
# 2                    0.434783                    0.869565
# 3                    0.563559                    0.822034
# 4                    0.593361                    0.751037
#
#    Trend_Agreement_dominance  Entry_Trigger_dominance  \
# 0                   0.769231                 0.836120
# 1                   0.813008                 0.849593
# 2                   0.913043                 0.913043
# 3                   0.872881                 0.851695
# 4                   0.804979                 0.958506
#
#    Entry_Confirmed_dominance  RHD_Bull_dominance  RHD_Bear_dominance
# 0                   0.963211            0.866221            0.969900
# 1                   0.967480            0.894309            0.939024
# 2                   0.956522            0.826087            0.956522
# 3                   0.961864            0.906780            0.932203
# 4                   0.987552            0.995851            0.829876
#
# [5 rows x 107 columns]

# %%
full_cluster_profile.to_csv("full_cluster_profile")
